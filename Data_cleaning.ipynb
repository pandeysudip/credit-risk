# %% [markdown]
# ## Data Source
# * https://resources.lendingclub.com/LoanStats_2019Q1.csv.zip
# * https://resources.lendingclub.com/LoanStats_2019Q2.csv.zip
# * https://resources.lendingclub.com/LoanStats_2019Q3.csv.zip
# * https://resources.lendingclub.com/LoanStats_2019Q4.csv.zip
# * https://resources.lendingclub.com/LoanStats_2020Q1.csv.zip

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2019 data (training data)

# %%
# Loading 2019 data
df1 = pd.read_csv(Path('Resources/Data/LoanStats_2019Q1.csv.zip'), skiprows=1)
df2 = pd.read_csv(Path('Resources/Data/LoanStats_2019Q2.csv.zip'), skiprows=1)
df3 = pd.read_csv(Path('Resources/Data/LoanStats_2019Q3.csv.zip'), skiprows=1)
df4 = pd.read_csv(Path('Resources/Data/LoanStats_2019Q4.csv.zip'), skiprows=1)

# %%
df1
# Out:
#                                                       id  member_id  \
# 0                                                    NaN        NaN
# 1                                                    NaN        NaN
# 2                                                    NaN        NaN
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# 115672                                               NaN        NaN
# 115673                                               NaN        NaN
# 115674                                               NaN        NaN
# 115675  Total amount funded in policy code 1: 1928448350        NaN
# 115676   Total amount funded in policy code 2: 799382986        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0         20000.0      20000.0          20000.0   60 months   17.19%
# 1         21225.0      21225.0          21225.0   60 months   14.74%
# 2          5000.0       5000.0           5000.0   36 months   17.97%
# 3         20000.0      20000.0          20000.0   36 months    8.19%
# 4         12000.0      12000.0          12000.0   60 months   15.57%
# ...           ...          ...              ...         ...      ...
# 115672    16000.0      16000.0          16000.0   36 months   16.14%
# 115673    16000.0      16000.0          16000.0   60 months   11.31%
# 115674    29250.0      29250.0          29250.0   60 months   18.94%
# 115675        NaN          NaN              NaN         NaN      NaN
# 115676        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade  ...  \
# 0            499.10     C        C5  ...
# 1            502.05     C        C2  ...
# 2            180.69     D        D1  ...
# 3            628.49     A        A4  ...
# 4            289.09     C        C3  ...
# ...             ...   ...       ...  ...
# 115672       563.62     C        C4  ...
# 115673       350.36     B        B3  ...
# 115674       757.80     D        D2  ...
# 115675          NaN   NaN       NaN  ...
# 115676          NaN   NaN       NaN  ...
#
#        orig_projected_additional_accrued_interest  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 115672                                        NaN
# 115673                                        NaN
# 115674                                        NaN
# 115675                                        NaN
# 115676                                        NaN
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# ...                               ...                          ...
# 115672                            NaN                          NaN
# 115673                            NaN                          NaN
# 115674                            NaN                          NaN
# 115675                            NaN                          NaN
# 115676                            NaN                          NaN
#
#         debt_settlement_flag debt_settlement_flag_date settlement_status  \
# 0                          N                       NaN               NaN
# 1                          N                       NaN               NaN
# 2                          N                       NaN               NaN
# 3                          N                       NaN               NaN
# 4                          N                       NaN               NaN
# ...                      ...                       ...               ...
# 115672                     N                       NaN               NaN
# 115673                     N                       NaN               NaN
# 115674                     N                       NaN               NaN
# 115675                   NaN                       NaN               NaN
# 115676                   NaN                       NaN               NaN
#
#        settlement_date settlement_amount  settlement_percentage  \
# 0                  NaN               NaN                    NaN
# 1                  NaN               NaN                    NaN
# 2                  NaN               NaN                    NaN
# 3                  NaN               NaN                    NaN
# 4                  NaN               NaN                    NaN
# ...                ...               ...                    ...
# 115672             NaN               NaN                    NaN
# 115673             NaN               NaN                    NaN
# 115674             NaN               NaN                    NaN
# 115675             NaN               NaN                    NaN
# 115676             NaN               NaN                    NaN
#
#         settlement_term
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 115672              NaN
# 115673              NaN
# 115674              NaN
# 115675              NaN
# 115676              NaN
#
# [115677 rows x 144 columns]

# %%
df1.shape
# Out:
# (115677, 144)

# %%
#removing last two rows which are nan
df1=df1[:-2]
df2=df2[:-2]
df3=df3[:-2]
df4=df4[:-2]
df1.shape
# Out:
# (115675, 144)

# %%
#Concating all 
df = pd.concat([df1, df2, df3, df4])
df
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0       NaN        NaN    20000.0      20000.0          20000.0   60 months
# 1       NaN        NaN    21225.0      21225.0          21225.0   60 months
# 2       NaN        NaN     5000.0       5000.0           5000.0   36 months
# 3       NaN        NaN    20000.0      20000.0          20000.0   36 months
# 4       NaN        NaN    12000.0      12000.0          12000.0   60 months
# ...     ...        ...        ...          ...              ...         ...
# 128253  NaN        NaN     3000.0       3000.0           3000.0   36 months
# 128254  NaN        NaN    10000.0      10000.0          10000.0   36 months
# 128255  NaN        NaN    19000.0      19000.0          19000.0   36 months
# 128256  NaN        NaN    10000.0      10000.0          10000.0   60 months
# 128257  NaN        NaN    14875.0      14875.0          14875.0   36 months
#
#        int_rate  installment grade sub_grade  ...  \
# 0        17.19%       499.10     C        C5  ...
# 1        14.74%       502.05     C        C2  ...
# 2        17.97%       180.69     D        D1  ...
# 3         8.19%       628.49     A        A4  ...
# 4        15.57%       289.09     C        C3  ...
# ...         ...          ...   ...       ...  ...
# 128253   17.74%       108.07     C        C5  ...
# 128254    6.46%       306.31     A        A1  ...
# 128255    6.46%       581.99     A        A1  ...
# 128256   28.80%       316.21     D        D5  ...
# 128257   16.95%       529.97     C        C4  ...
#
#        orig_projected_additional_accrued_interest  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 128253                                        NaN
# 128254                                        NaN
# 128255                                        NaN
# 128256                                        NaN
# 128257                                        NaN
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# ...                               ...                          ...
# 128253                            NaN                          NaN
# 128254                            NaN                          NaN
# 128255                            NaN                          NaN
# 128256                            NaN                          NaN
# 128257                            NaN                          NaN
#
#         debt_settlement_flag debt_settlement_flag_date settlement_status  \
# 0                          N                       NaN               NaN
# 1                          N                       NaN               NaN
# 2                          N                       NaN               NaN
# 3                          N                       NaN               NaN
# 4                          N                       NaN               NaN
# ...                      ...                       ...               ...
# 128253                     N                       NaN               NaN
# 128254                     N                       NaN               NaN
# 128255                     N                       NaN               NaN
# 128256                     N                       NaN               NaN
# 128257                     N                       NaN               NaN
#
#        settlement_date settlement_amount  settlement_percentage  \
# 0                  NaN               NaN                    NaN
# 1                  NaN               NaN                    NaN
# 2                  NaN               NaN                    NaN
# 3                  NaN               NaN                    NaN
# 4                  NaN               NaN                    NaN
# ...                ...               ...                    ...
# 128253             NaN               NaN                    NaN
# 128254             NaN               NaN                    NaN
# 128255             NaN               NaN                    NaN
# 128256             NaN               NaN                    NaN
# 128257             NaN               NaN                    NaN
#
#         settlement_term
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 128253              NaN
# 128254              NaN
# 128255              NaN
# 128256              NaN
# 128257              NaN
#
# [518107 rows x 144 columns]

# %%
#selecting important columns
columns = [
    "loan_amnt", "int_rate", "installment", "home_ownership", "annual_inc", 
    "verification_status", "pymnt_plan", "dti", "delinq_2yrs", 
    "inq_last_6mths", "open_acc", "pub_rec", "revol_bal", "total_acc", 
    "initial_list_status", "out_prncp", "out_prncp_inv", "total_pymnt", 
    "total_pymnt_inv", "total_rec_prncp", "total_rec_int", 
    "total_rec_late_fee", "recoveries", "collection_recovery_fee", 
    "last_pymnt_amnt", "collections_12_mths_ex_med", "policy_code", 
    "application_type", "acc_now_delinq", "tot_coll_amt", "tot_cur_bal", 
    "open_acc_6m", "open_act_il", "open_il_12m", "open_il_24m", 
    "mths_since_rcnt_il", "total_bal_il", "il_util", "open_rv_12m", 
    "open_rv_24m", "max_bal_bc", "all_util", "total_rev_hi_lim", "inq_fi", 
    "total_cu_tl", "inq_last_12m", "acc_open_past_24mths", "avg_cur_bal", 
    "bc_open_to_buy", "bc_util", "chargeoff_within_12_mths", "delinq_amnt", 
    "mo_sin_old_il_acct", "mo_sin_old_rev_tl_op", "mo_sin_rcnt_rev_tl_op", 
    "mo_sin_rcnt_tl", "mort_acc", "mths_since_recent_bc", 
    "mths_since_recent_inq", "num_accts_ever_120_pd", "num_actv_bc_tl",
    "num_actv_rev_tl", "num_bc_sats", "num_bc_tl", "num_il_tl", 
    "num_op_rev_tl", "num_rev_accts", "num_rev_tl_bal_gt_0", "num_sats", 
    "num_tl_120dpd_2m", "num_tl_30dpd", "num_tl_90g_dpd_24m", 
    "num_tl_op_past_12m", "pct_tl_nvr_dlq", "percent_bc_gt_75", 
    "pub_rec_bankruptcies", "tax_liens", "tot_hi_cred_lim", 
    "total_bal_ex_mort", "total_bc_limit", "total_il_high_credit_limit", 
    "hardship_flag", "debt_settlement_flag",
    "loan_status"
]

target = "loan_status"

# %%
# only selecting important columns
df = df.loc[:, columns].copy()
df
# Out:
#         loan_amnt int_rate  installment home_ownership  annual_inc  \
# 0         20000.0   17.19%       499.10           RENT     47000.0
# 1         21225.0   14.74%       502.05       MORTGAGE    225000.0
# 2          5000.0   17.97%       180.69       MORTGAGE     62000.0
# 3         20000.0    8.19%       628.49       MORTGAGE    200000.0
# 4         12000.0   15.57%       289.09       MORTGAGE     49000.0
# ...           ...      ...          ...            ...         ...
# 128253     3000.0   17.74%       108.07            OWN     44000.0
# 128254    10000.0    6.46%       306.31           RENT     60000.0
# 128255    19000.0    6.46%       581.99       MORTGAGE     67350.0
# 128256    10000.0   28.80%       316.21       MORTGAGE     40000.0
# 128257    14875.0   16.95%       529.97       MORTGAGE    150000.0
#
#        verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  \
# 0          Source Verified          n  14.02          0.0             1.0
# 1             Not Verified          n  16.80          0.0             2.0
# 2             Not Verified          n  19.82          1.0             0.0
# 3             Not Verified          n  22.66          1.0             0.0
# 4          Source Verified          n  13.47          0.0             0.0
# ...                    ...        ...    ...          ...             ...
# 128253        Not Verified          n  30.01          0.0             1.0
# 128254        Not Verified          n  14.18          0.0             0.0
# 128255     Source Verified          n   6.00          0.0             0.0
# 128256        Not Verified          n   2.10          0.0             0.0
# 128257     Source Verified          n   8.76          0.0             0.0
#
#         ...  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0       ...              12.5                   0.0        0.0
# 1       ...              50.0                   1.0        0.0
# 2       ...              50.0                   0.0        0.0
# 3       ...              22.2                   0.0        0.0
# 4       ...              14.3                   0.0        0.0
# ...     ...               ...                   ...        ...
# 128253  ...               0.0                   0.0        0.0
# 128254  ...               0.0                   0.0        0.0
# 128255  ...              33.3                   0.0        0.0
# 128256  ...              33.3                   1.0        0.0
# 128257  ...              72.7                   0.0        0.0
#
#         tot_hi_cred_lim total_bal_ex_mort  total_bc_limit  \
# 0               75824.0           31546.0         33800.0
# 1              747075.0          209426.0         53500.0
# 2              255738.0           31615.0          9400.0
# 3              448069.0           84744.0         49400.0
# 4              189260.0          106025.0         24400.0
# ...                 ...               ...             ...
# 128253          63484.0           51462.0          4800.0
# 128254          78282.0           23872.0         66700.0
# 128255          47700.0           21809.0         47700.0
# 128256           7400.0            1947.0          4600.0
# 128257         180600.0           43530.0         46300.0
#
#         total_il_high_credit_limit  hardship_flag  debt_settlement_flag  \
# 0                          21524.0              N                     N
# 1                         128175.0              N                     N
# 2                          39938.0              N                     N
# 3                         105180.0              N                     N
# 4                          68860.0              N                     N
# ...                            ...            ...                   ...
# 128253                     50684.0              N                     N
# 128254                     11282.0              N                     N
# 128255                         0.0              N                     N
# 128256                         0.0              N                     N
# 128257                         0.0              N                     N
#
#         loan_status
# 0            Issued
# 1            Issued
# 2            Issued
# 3            Issued
# 4            Issued
# ...             ...
# 128253   Fully Paid
# 128254      Current
# 128255   Fully Paid
# 128256      Current
# 128257   Fully Paid
#
# [518107 rows x 84 columns]

# %%
#looking for nan value
df.isna().sum()
# Out:
# loan_amnt                         0
# int_rate                          0
# installment                       0
# home_ownership                    0
# annual_inc                        0
#                               ...
# total_bc_limit                    0
# total_il_high_credit_limit        0
# hardship_flag                 26866
# debt_settlement_flag              0
# loan_status                       0
# Length: 84, dtype: int64

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

df.isna().sum()
# Out:
# loan_amnt                     0
# int_rate                      0
# installment                   0
# home_ownership                0
# annual_inc                    0
#                              ..
# total_bc_limit                0
# total_il_high_credit_limit    0
# hardship_flag                 0
# debt_settlement_flag          0
# loan_status                   0
# Length: 84, dtype: int64

# %%
df.shape
# Out:
# (369038, 84)

# %%
# convert interest rate to numerical
df['int_rate'] = df['int_rate'].str.replace('%', '')
df['int_rate'] = df['int_rate'].astype('float') / 100

# %%
# Remove the `Issued` loan status
df = df[df['loan_status'] != 'Issued']

# %%
df['loan_status'].value_counts()
# Out:
# Current               274072
# Fully Paid             63199
# Charged Off            11957
# Late (31-120 days)      2745
# In Grace Period         2584
# Late (16-30 days)        709
# Default                   52
# Name: loan_status, dtype: int64

# %%
# Convert the target column values to low_risk and high_risk based on their values
x = {'Current': 'low_risk'}   
df = df.replace(x)
#using dict.fromkeys in which first will be keys and second will be value
x = dict.fromkeys(['Late (31-120 days)', 'Late (16-30 days)', 'Default', 'In Grace Period'], 'high_risk')    
df = df.replace(x)

df['loan_status'].value_counts()
# Out:
# low_risk       274072
# Fully Paid      63199
# Charged Off     11957
# high_risk        6090
# Name: loan_status, dtype: int64

# %%
#Only considering low risk and high risk rows
low_risk_rows = df[df['loan_status'] == 'low_risk']
high_risk_rows = df[df['loan_status'] == 'high_risk']
low_risk_rows
# Out:
#         loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 93        10500.0    0.1719       375.35           RENT     66000.0
# 99        25000.0    0.2000       929.09       MORTGAGE    105000.0
# 132       20000.0    0.2000       529.88       MORTGAGE     56000.0
# 133       10000.0    0.1640       353.55           RENT     92000.0
# 140       22000.0    0.1474       520.39       MORTGAGE     52000.0
# ...           ...       ...          ...            ...         ...
# 128244    34025.0    0.1240       763.77           RENT     92000.0
# 128245     1200.0    0.1171        39.70       MORTGAGE     65000.0
# 128246    24000.0    0.1695       595.82       MORTGAGE     95000.0
# 128247    17175.0    0.1862       626.28       MORTGAGE    115000.0
# 128248    18000.0    0.1774       454.54       MORTGAGE    149400.0
#
#        verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  \
# 93         Source Verified          n  27.24          0.0             0.0
# 99                Verified          n  20.23          0.0             0.0
# 132               Verified          n  24.26          0.0             0.0
# 133               Verified          n  31.44          0.0             1.0
# 140           Not Verified          n  18.76          0.0             1.0
# ...                    ...        ...    ...          ...             ...
# 128244     Source Verified          n  17.57          0.0             0.0
# 128245            Verified          n  21.23          0.0             0.0
# 128246            Verified          n  22.83          0.0             1.0
# 128247        Not Verified          n   7.53          4.0             1.0
# 128248     Source Verified          n  12.29          2.0             3.0
#
#         ...  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 93      ...             100.0                   0.0        0.0
# 99      ...              50.0                   1.0        0.0
# 132     ...              50.0                   0.0        0.0
# 133     ...              50.0                   1.0        0.0
# 140     ...               0.0                   0.0        0.0
# ...     ...               ...                   ...        ...
# 128244  ...              25.0                   0.0        0.0
# 128245  ...              40.0                   0.0        0.0
# 128246  ...               0.0                   0.0        0.0
# 128247  ...               0.0                   0.0        0.0
# 128248  ...               0.0                   0.0        0.0
#
#         tot_hi_cred_lim total_bal_ex_mort  total_bc_limit  \
# 93              65687.0           38199.0          2000.0
# 99             271427.0           60641.0         41200.0
# 132             60644.0           45684.0          7500.0
# 133             99506.0           68784.0         19700.0
# 140            219750.0           25919.0         27600.0
# ...                 ...               ...             ...
# 128244          85020.0           43307.0         26700.0
# 128245         246116.0           42308.0         35700.0
# 128246         358528.0           74346.0         31500.0
# 128247         277357.0            9285.0         14500.0
# 128248        1281222.0           45456.0          9000.0
#
#         total_il_high_credit_limit  hardship_flag  debt_settlement_flag  \
# 93                         61987.0              N                     N
# 99                         49197.0              N                     N
# 132                        43144.0              N                     N
# 133                        76506.0              N                     N
# 140                        20000.0              N                     N
# ...                            ...            ...                   ...
# 128244                     30999.0              N                     N
# 128245                     41477.0              N                     N
# 128246                     86474.0              N                     N
# 128247                     25029.0              N                     N
# 128248                     37916.0              N                     N
#
#         loan_status
# 93         low_risk
# 99         low_risk
# 132        low_risk
# 133        low_risk
# 140        low_risk
# ...             ...
# 128244     low_risk
# 128245     low_risk
# 128246     low_risk
# 128247     low_risk
# 128248     low_risk
#
# [274072 rows x 84 columns]

# %%
#under sampling
#df = pd.concat([low_risk_rows, high_risk_rows.sample(n=len(low_risk_rows), replace=True)])
df = pd.concat([low_risk_rows.sample(n=len(high_risk_rows), random_state=42), high_risk_rows])
df = df.reset_index(drop=True)
df
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0         7000.0    0.1894       256.38       MORTGAGE     75000.0
# 1        40000.0    0.1614       975.71       MORTGAGE    102000.0
# 2        11000.0    0.2055       294.81           RENT     45000.0
# 3         4000.0    0.1612       140.87       MORTGAGE     38000.0
# 4        14000.0    0.1797       505.93       MORTGAGE     43000.0
# ...          ...       ...          ...            ...         ...
# 12175    19975.0    0.2565       801.09           RENT     28000.0
# 12176    15000.0    0.1774       540.34           RENT     50000.0
# 12177     3600.0    0.1862       131.28           RENT     60000.0
# 12178    15000.0    0.0881       475.68       MORTGAGE     62000.0
# 12179    15000.0    0.1774       540.34           RENT     54080.0
#
#       verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0            Not Verified          n  28.62          0.0             2.0  ...
# 1         Source Verified          n  11.72          2.0             0.0  ...
# 2                Verified          n  37.25          1.0             3.0  ...
# 3            Not Verified          n  42.89          1.0             0.0  ...
# 4         Source Verified          n  22.16          1.0             0.0  ...
# ...                   ...        ...    ...          ...             ...  ...
# 12175        Not Verified          n  28.42          0.0             0.0  ...
# 12176            Verified          n  23.43          4.0             0.0  ...
# 12177        Not Verified          n  28.80          0.0             1.0  ...
# 12178     Source Verified          n  11.44          0.0             0.0  ...
# 12179        Not Verified          n  21.66          1.0             1.0  ...
#
#        percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0                  87.5                   0.0        0.0         352260.0
# 1                   0.0                   0.0        0.0         294664.0
# 2                   7.7                   0.0        0.0          92228.0
# 3                 100.0                   0.0        0.0         284273.0
# 4                  25.0                   0.0        0.0         120280.0
# ...                 ...                   ...        ...              ...
# 12175              16.7                   0.0        0.0          50055.0
# 12176              11.1                   0.0        0.0          70324.0
# 12177               0.0                   0.0        0.0          83765.0
# 12178               0.0                   0.0        0.0         189930.0
# 12179             100.0                   0.0        0.0          48968.0
#
#       total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0               62666.0         35000.0                     10000.0
# 1              109911.0          9000.0                     71044.0
# 2               36007.0         33000.0                     46328.0
# 3               52236.0         13500.0                     52017.0
# 4               88147.0         33300.0                     78680.0
# ...                 ...             ...                         ...
# 12175           28192.0         18700.0                     19055.0
# 12176           57025.0         13300.0                     54824.0
# 12177           55156.0         14800.0                     53065.0
# 12178           23748.0          7000.0                     32930.0
# 12179           29786.0          2900.0                     33968.0
#
#        hardship_flag  debt_settlement_flag  loan_status
# 0                  N                     N     low_risk
# 1                  N                     N     low_risk
# 2                  N                     N     low_risk
# 3                  N                     N     low_risk
# 4                  N                     N     low_risk
# ...              ...                   ...          ...
# 12175              N                     N    high_risk
# 12176              N                     N    high_risk
# 12177              N                     N    high_risk
# 12178              N                     N    high_risk
# 12179              N                     N    high_risk
#
# [12180 rows x 84 columns]

# %%
df['loan_status'].value_counts()
# Out:
# low_risk     6090
# high_risk    6090
# Name: loan_status, dtype: int64

# %%
#saving the data for modeling
df.to_csv('Resources/cleaned-data/2019loans_us.csv', index=False)

# %%
#over sampling
df_over=pd.concat([low_risk_rows, high_risk_rows.sample(n=len(low_risk_rows), replace=True)])
df_over= df_over.reset_index(drop=True)
df_over
# Out:
#         loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0         10500.0    0.1719       375.35           RENT     66000.0
# 1         25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2         20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3         10000.0    0.1640       353.55           RENT     92000.0
# 4         22000.0    0.1474       520.39       MORTGAGE     52000.0
# ...           ...       ...          ...            ...         ...
# 548139     4400.0    0.2000       163.52           RENT     41000.0
# 548140    32000.0    0.1308      1079.44       MORTGAGE    210000.0
# 548141    40000.0    0.1695       993.03       MORTGAGE    140000.0
# 548142     5275.0    0.1308       177.94           RENT     19464.0
# 548143    10000.0    0.1240       334.06       MORTGAGE     49000.0
#
#        verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  \
# 0          Source Verified          n  27.24          0.0             0.0
# 1                 Verified          n  20.23          0.0             0.0
# 2                 Verified          n  24.26          0.0             0.0
# 3                 Verified          n  31.44          0.0             1.0
# 4             Not Verified          n  18.76          0.0             1.0
# ...                    ...        ...    ...          ...             ...
# 548139        Not Verified          n  31.82          0.0             0.0
# 548140        Not Verified          n  16.15          0.0             0.0
# 548141     Source Verified          n  27.79          0.0             2.0
# 548142        Not Verified          n  30.21          0.0             0.0
# 548143        Not Verified          n  25.77          1.0             1.0
#
#         ...  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0       ...             100.0                   0.0        0.0
# 1       ...              50.0                   1.0        0.0
# 2       ...              50.0                   0.0        0.0
# 3       ...              50.0                   1.0        0.0
# 4       ...               0.0                   0.0        0.0
# ...     ...               ...                   ...        ...
# 548139  ...               0.0                   0.0        0.0
# 548140  ...             100.0                   0.0        0.0
# 548141  ...              20.0                   0.0        0.0
# 548142  ...             100.0                   0.0        0.0
# 548143  ...               0.0                   0.0        0.0
#
#         tot_hi_cred_lim total_bal_ex_mort  total_bc_limit  \
# 0               65687.0           38199.0          2000.0
# 1              271427.0           60641.0         41200.0
# 2               60644.0           45684.0          7500.0
# 3               99506.0           68784.0         19700.0
# 4              219750.0           25919.0         27600.0
# ...                 ...               ...             ...
# 548139          38014.0           27390.0          5400.0
# 548140         378319.0          101528.0         50700.0
# 548141         312730.0          104873.0         16500.0
# 548142          16500.0           11497.0          3700.0
# 548143         127328.0           46045.0         74100.0
#
#         total_il_high_credit_limit  hardship_flag  debt_settlement_flag  \
# 0                          61987.0              N                     N
# 1                          49197.0              N                     N
# 2                          43144.0              N                     N
# 3                          76506.0              N                     N
# 4                          20000.0              N                     N
# ...                            ...            ...                   ...
# 548139                     25314.0              N                     N
# 548140                     59675.0              N                     N
# 548141                    120054.0              N                     N
# 548142                      3000.0              N                     N
# 548143                     39028.0              N                     N
#
#         loan_status
# 0          low_risk
# 1          low_risk
# 2          low_risk
# 3          low_risk
# 4          low_risk
# ...             ...
# 548139    high_risk
# 548140    high_risk
# 548141    high_risk
# 548142    high_risk
# 548143    high_risk
#
# [548144 rows x 84 columns]

# %%
df_over['loan_status'].value_counts()
# Out:
# low_risk     274072
# high_risk    274072
# Name: loan_status, dtype: int64

# %%
#saving the data for modeling
df_over.to_csv('Resources/cleaned-data/2019loans_os.csv', index=False)

# %% [markdown]
# ## 2020 data (Test data)

# %%
# Load the data
validate_df = pd.read_csv(Path('Resources/Data/LoanStats_2020Q1.csv.zip'), skiprows=1)[:-2]
validate_df = validate_df.loc[:, columns].copy()

# %%
# Drop the null columns where all values are null
validate_df = validate_df.dropna(axis='columns', how='all')

# Drop the null rows
validate_df = validate_df.dropna()

# %%
# convert interest rate to numerical
validate_df['int_rate'] = validate_df['int_rate'].str.replace('%', '')
validate_df['int_rate'] = validate_df['int_rate'].astype('float') / 100

# %%
# Remove the `Issued` loan status
validate_df =validate_df[validate_df['loan_status'] != 'Issued']

# %%
# Convert the target column values to low_risk and high_risk based on their values
x = dict.fromkeys(['Current', 'Fully Paid'], 'low_risk') 
validate_df = validate_df.replace(x)

x = dict.fromkeys(['Late (31-120 days)', 'Late (16-30 days)', 'Default', 'In Grace Period', 'Charged Off'], 'high_risk')    
validate_df = validate_df.replace(x)

# %%
low_risk_rows1 = validate_df[validate_df['loan_status'] == 'low_risk']
high_risk_rows1 = validate_df[validate_df['loan_status'] == 'high_risk']
low_risk_rows1.shape
# Out:
# (2351, 84)

# %%
#under sampling
validate_df = pd.concat([low_risk_rows1.sample(n=len(high_risk_rows1), random_state=37), high_risk_rows1])
validate_df = validate_df.reset_index(drop=True)
validate_df
# Out:
#       loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0       40000.0    0.1033       856.40           RENT    128700.0
# 1       24450.0    0.1430       572.72       MORTGAGE     44574.0
# 2       13500.0    0.1430       316.23            OWN     60000.0
# 3       10625.0    0.1774       268.31           RENT     60000.0
# 4        6375.0    0.1862       232.46           RENT     60000.0
# ...         ...       ...          ...            ...         ...
# 4697    30000.0    0.1240       673.42           RENT    140480.0
# 4698    24000.0    0.0756       747.22           RENT     50000.0
# 4699    10000.0    0.2305       387.36           RENT     33000.0
# 4700     8000.0    0.1862       205.86           RENT     38000.0
# 4701    30000.0    0.2055      1123.34           RENT    180000.0
#
#      verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0        Source Verified          n  12.47          0.0             1.0  ...
# 1           Not Verified          n  15.05          0.0             1.0  ...
# 2           Not Verified          n  28.72          0.0             0.0  ...
# 3               Verified          n  15.70          0.0             4.0  ...
# 4        Source Verified          n  35.50          0.0             0.0  ...
# ...                  ...        ...    ...          ...             ...  ...
# 4697     Source Verified          n  15.74          0.0             0.0  ...
# 4698        Not Verified          n  26.81          0.0             0.0  ...
# 4699            Verified          n  38.51          0.0             2.0  ...
# 4700     Source Verified          n  16.36          0.0             1.0  ...
# 4701     Source Verified          n  12.06          0.0             0.0  ...
#
#       percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0                 57.1                   0.0        0.0          63915.0
# 1                  0.0                   0.0        0.0         136425.0
# 2                  0.0                   0.0        0.0          82124.0
# 3                 20.0                   0.0        0.0          54855.0
# 4                 75.0                   0.0        0.0          90445.0
# ...                ...                   ...        ...              ...
# 4697              28.6                   0.0        0.0         159688.0
# 4698               0.0                   0.0        0.0          62375.0
# 4699               0.0                   0.0        0.0          43250.0
# 4700               0.0                   1.0        0.0          31357.0
# 4701              33.3                   0.0        0.0         218686.0
#
#      total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0              49510.0         49400.0                     14515.0
# 1              19439.0         15500.0                     18925.0
# 2              65000.0          5400.0                     61724.0
# 3              50335.0         23200.0                     26255.0
# 4              56541.0         15300.0                     72345.0
# ...                ...             ...                         ...
# 4697          110873.0         48400.0                    107388.0
# 4698           18928.0         13300.0                     30775.0
# 4699           33022.0          8500.0                     29550.0
# 4700           19595.0          1500.0                      9657.0
# 4701          209389.0          5600.0                    209986.0
#
#       hardship_flag  debt_settlement_flag  loan_status
# 0                 Y                     N     low_risk
# 1                 N                     N     low_risk
# 2                 Y                     N     low_risk
# 3                 N                     N     low_risk
# 4                 N                     N     low_risk
# ...             ...                   ...          ...
# 4697              N                     N    high_risk
# 4698              N                     N    high_risk
# 4699              N                     N    high_risk
# 4700              N                     N    high_risk
# 4701              N                     N    high_risk
#
# [4702 rows x 84 columns]

# %%
#saving data for testing purpose
validate_df.to_csv('Resources/cleaned-data/2020Q1loans_us.csv', index=False)

# %%
#Over sampling
validate_df_over = pd.concat([low_risk_rows1, high_risk_rows1.sample(n=len(low_risk_rows1), replace=True)])
validate_df_over  = validate_df_over.reset_index(drop=True)
validate_df_over
# Out:
#       loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0       40000.0    0.1033       856.40           RENT    128700.0
# 1       24450.0    0.1430       572.72       MORTGAGE     44574.0
# 2       13500.0    0.1430       316.23            OWN     60000.0
# 3       10625.0    0.1774       268.31           RENT     60000.0
# 4        6375.0    0.1862       232.46           RENT     60000.0
# ...         ...       ...          ...            ...         ...
# 4697    20200.0    0.2565       810.11       MORTGAGE     70000.0
# 4698     4500.0    0.0819       141.41           RENT     30000.0
# 4699    25000.0    0.2305       705.49           RENT    110000.0
# 4700     5000.0    0.0819       157.13           RENT     90000.0
# 4701    30000.0    0.2055      1123.34           RENT     75000.0
#
#      verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0        Source Verified          n  12.47          0.0             1.0  ...
# 1           Not Verified          n  15.05          0.0             1.0  ...
# 2           Not Verified          n  28.72          0.0             0.0  ...
# 3               Verified          n  15.70          0.0             4.0  ...
# 4        Source Verified          n  35.50          0.0             0.0  ...
# ...                  ...        ...    ...          ...             ...  ...
# 4697        Not Verified          n  18.96          2.0             0.0  ...
# 4698     Source Verified          n  15.80          0.0             1.0  ...
# 4699        Not Verified          n  14.12          0.0             0.0  ...
# 4700        Not Verified          n  22.32          0.0             1.0  ...
# 4701        Not Verified          n  30.96          0.0             0.0  ...
#
#       percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0                 57.1                   0.0        0.0          63915.0
# 1                  0.0                   0.0        0.0         136425.0
# 2                  0.0                   0.0        0.0          82124.0
# 3                 20.0                   0.0        0.0          54855.0
# 4                 75.0                   0.0        0.0          90445.0
# ...                ...                   ...        ...              ...
# 4697              44.4                   0.0        0.0         301948.0
# 4698              50.0                   0.0        0.0          21379.0
# 4699              12.5                   0.0        0.0          69274.0
# 4700               0.0                   0.0        0.0          79517.0
# 4701              45.5                   0.0        0.0          88000.0
#
#      total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0              49510.0         49400.0                     14515.0
# 1              19439.0         15500.0                     18925.0
# 2              65000.0          5400.0                     61724.0
# 3              50335.0         23200.0                     26255.0
# 4              56541.0         15300.0                     72345.0
# ...                ...             ...                         ...
# 4697           41050.0         24900.0                     35234.0
# 4698            9664.0         10900.0                     10079.0
# 4699           46964.0         43500.0                     25774.0
# 4700           47435.0         12800.0                     63717.0
# 4701           60613.0         41300.0                     43600.0
#
#       hardship_flag  debt_settlement_flag  loan_status
# 0                 Y                     N     low_risk
# 1                 N                     N     low_risk
# 2                 Y                     N     low_risk
# 3                 N                     N     low_risk
# 4                 N                     N     low_risk
# ...             ...                   ...          ...
# 4697              N                     N    high_risk
# 4698              N                     N    high_risk
# 4699              N                     N    high_risk
# 4700              N                     N    high_risk
# 4701              N                     N    high_risk
#
# [4702 rows x 84 columns]

# %%
#saving data for testing purpose
validate_df_over.to_csv('Resources/cleaned-data/2020Q1loans_os.csv', index=False)
